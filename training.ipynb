# %%
# !python train.py --dataset tiny --steps 3000
# Out:
# Using device: cuda
# ...
# Dataset: 338,025 tokens
# Model parameters: 21,259,392 (unique, with weight tying)
#   Null copies M = 8, total routing slots = 16
#
# ...
# Step 1/3000 | LR: 3.00e-06 | 202 tok/s
#   Loss: 10.9052 (LM: 10.8737, Bal: 1.1712, Z: 8.0320)
#   Perplexity: 48771.01
#   Null routing: 34.7% | Zero-compute tokens: 15.8%
#   Expert utilization:
#     E0 |████████████████              | 1238
#     E1 |██████████████████████████████| 2306
#     E2 |█████████████████             | 1308
#     E3 |███████████████               | 1213
#     E4 |███████████████               | 1196
#     E5 |██████████                    | 833
#     E6 |██████████████████            | 1394
#     E7 |███████████████               | 1214
#   Generated: First Citizen:
# Before we proceed any further, coincidence textsseed pegged Safety Telescope NinthbalanceYRWal machine Rare Helsinki redundancyitate WATCHED RPG Cant PAY Compliance tadACH366 unnecess P
#
# ...
# Step 50/3000 | LR: 1.50e-04 | 4,225 tok/s
# ...

# %%
# !python visualize.py
# Out:
# Loading telemetry from telemetry.json...
# Loaded 3000 steps of telemetry data.
# Plotting training loss curves...
# Figure(1000x500)
# Plotting perplexity...
# Figure(1000x500)
# Plotting expert utilization heatmap...
# Figure(1000x600)
# Plotting null routing ratio...
# Figure(1000x500)
# Plotting expert token distribution...
# Figure(800x500)
# Plotting zero-compute token ratio...
# Figure(1000x500)
# Plotting gate weight distributions...
# Figure(1400x500)
#
# All plots saved to ./
